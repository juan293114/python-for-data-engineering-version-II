# %%
dim_weather_region = spark.createDataFrame(
    [
        (1, "Costa", "Región costera del Perú"),
        (2, "Sierra", "Región andina del Perú"),
        (3, "Selva", "Región amazónica del Perú")
    ],
    [
        "weather_region_id",
        "weather_region",
        "description"
    ]
)

dim_weather_region.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable(
        "workspace.weather_gold.dim_weather_region"
    )

# %%
# %sql
select * from workspace.weather_gold.dim_weather_region limit 5
