# %%
# %pip install kagglehub
# %pip install pendulum
# %pip install gdown -q

# %%
import kagglehub
from pathlib import Path
import pendulum
import gdown

# %%
current_catalog = spark.sql("select current_catalog()").first()[0]
catalog = current_catalog
schema = "raw"
volume = "datos"
fuente=  "fuente"

# %%
ruta = f"/Volumes/{catalog}/{schema}/{volume}"
ruta_fuente = f"{ruta}/{fuente}"

# Crea esquema y volumen si no existen

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {catalog}.{schema}.{volume}")
dbutils.fs.mkdirs(ruta_fuente)

# %%
# Elimina todos los archivos y subcarpetas dentro de la ruta
dbutils.fs.rm(ruta_fuente, recurse=True)

# %%
dbutils.widgets.text("output_dir", "/Volumes/workspace/raw/datos/fuente", "Output Directory")
dbutils.widgets.text("id_sheet", "11iTOsth2bocuCo-YhJ1eI1Y4dBvzi6nn6htZ_TojQPk", "ID Archivo")

# %%
#Leer valores de los widgets
id_sheet = Path(dbutils.widgets.get("id_sheet"))
output_dir = Path(dbutils.widgets.get("output_dir"))

# %%
import kagglehub

ruta_raw = output_dir

path = kagglehub.dataset_download(
    "papasricas/datos-de-venta-de-tiendas-en-peru10midatos",
    output_dir=ruta_raw
)
print(path)

# %%
url_csv = f"https://docs.google.com/spreadsheets/d/{id_sheet}/export?format=csv"
# Definir el nombre del archivo en raw
archivo_csv = ruta_raw / "worldcities.csv"
# Descargar el archivo CSV
gdown.download(url=url_csv, output=str(archivo_csv), quiet=False)
print(f"Archivo guardado en raw: {archivo_csv}")

# %%
ruta = Path(ruta_raw)

for archivo in ruta.iterdir():
    print(archivo)
