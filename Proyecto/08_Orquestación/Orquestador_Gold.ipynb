# %%
# Dimensiones primero, luego la fact table (no hay dependencia real entre ellas, pero mantiene un orden lógico)
motores_gold = [
    ("dim_products",    "../06_Gold/Motor_Gold_Dim_Products"),
    ("dim_users",       "../06_Gold/Motor_Gold_Dim_Users"),
    ("fact_cart_items", "../06_Gold/Motor_Gold_Fact_Cart_Items"),
]

for nombre, ruta in motores_gold:
    resultado = dbutils.notebook.run(ruta, timeout_seconds=600)
    print(f"{nombre}: {resultado}")
