# %% [markdown]
# ### CREAR LOS REPOSITORIOS DE DATOS

# %%
# %sql
CREATE CATALOG IF NOT EXISTS proyecto_spotify;

CREATE SCHEMA IF NOT EXISTS proyecto_spotify.raw;

CREATE SCHEMA IF NOT EXISTS proyecto_spotify.bronze;

CREATE SCHEMA IF NOT EXISTS proyecto_spotify.silver;

CREATE SCHEMA IF NOT EXISTS proyecto_spotify.gold;
