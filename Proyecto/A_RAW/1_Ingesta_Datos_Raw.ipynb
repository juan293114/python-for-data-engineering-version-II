# %%
catalog = "internet_fijo_elt"
schema = "raw"
volume = "archivos_internet_fijo"

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}")

# %%
# Crea esquema y volumen si no existen
spark.sql(f"CREATE VOLUME IF NOT EXISTS {catalog}.{schema}.{volume}")

# %% [markdown]
# Tras crear el Volume, agregamos el documento CONEXIONES_INTERNET_FIJO_DISTRITO.xlsx
