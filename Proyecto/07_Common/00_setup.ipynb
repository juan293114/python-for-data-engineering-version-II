# %%
import requests
from requests.adapters import HTTPAdapter
import pandas as pd
from pathlib import Path
import json
from datetime import datetime 
from urllib3.util.retry import Retry
from pyspark.sql import functions as F
from pyspark.sql import DataFrame

import json
import uuid
import hashlib
from datetime import date, datetime

from pyspark.sql.types import StructType, StructField, StringType, BooleanType, TimestampType, LongType

# ---- Variables globales (nombres de catálogo/esquemas) ----
CATALOGO       = "workspace"
ESQUEMA_CONTROL = "control"
ESQUEMA_RAW     = "raw"
ESQUEMA_BRONZE  = "bronze"
ESQUEMA_SILVER  = "silver"
ESQUEMA_GOLD    = "gold"

# %%
f"Se realizó con éxito la carga"
