# %%
import requests
import pandas as pd
# My commet
r = requests.get("https://api.tvmaze.com/schedule/web", params={"date": "2026-03-01"}, timeout=30)
print(r.status_code)

print(r.json())

# %%
df = pd.json_normalize(r.json())  # aplana JSON a columnas

df.head()

# %%
print(df.shape)

# %%
print(df.columns.tolist())

# %%
print(df.shape)
print("hello world")

# %%
print("Hello world")

# %%
print("Hello world Jose Benitez 1")
#COMENTARIO

# %%
print("Hello world Jose Benitez 111")

# %%
print("Prueba numero 2 gc")

# %%
print('Hellor world')
